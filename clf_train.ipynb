# %%
import pandas as pd
import numpy as np
import joblib

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier

# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.4.0-py3-none-any.whl.metadata (38 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in .\venv\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in .\venv\lib\site-packages (from kagglehub) (6.0.3)
# Collecting requests (from kagglehub)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm in .\venv\lib\site-packages (from kagglehub) (4.67.1)
# Collecting protobuf (from kagglesdk<1.0,>=0.1.14->kagglehub)
#   Downloading protobuf-6.33.4-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting charset_normalizer<4,>=2 (from requests->kagglehub)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests->kagglehub) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests->kagglehub)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests->kagglehub) (2026.1.4)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.4.0-py3-none-any.whl (69 kB)
# Downloading kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Downloading protobuf-6.33.4-cp310-abi3-win_amd64.whl (436 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Installing collected packages: urllib3, protobuf, charset_normalizer, requests, kagglesdk, kagglehub
#
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------ --------------------------------- 1/6 [protobuf]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    -------------------- ------------------- 3/6 [requests]
#    -------------------- ------------------- 3/6 [requests]
#    -------------------- ------------------- 3/6 [requests]
#    -------------------- ------------------- 3/6 [requests]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    --------------------------------- ------ 5/6 [kagglehub]
#    ---------------------------------------- 6/6 [kagglehub]
#
# Successfully installed charset_normalizer-3.4.4 kagglehub-0.4.0 kagglesdk-0.1.15 protobuf-6.33.4 requests-2.32.5 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('water_potability.csv')

# Display first few rows
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
X = df.drop("Potability", axis=1)
y = df["Potability"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
def clip_outliers(X):
    X = pd.DataFrame(X)
    for col in X.columns:
        X[col] = X[col].clip(
            X[col].quantile(0.01),
            X[col].quantile(0.99)
        )
    return X.values

# %%
def add_features(X):
    X = pd.DataFrame(X)

    solids = X.iloc[:, 2]
    conductivity = X.iloc[:, 5]
    organic = X.iloc[:, 6]

    X["solids_per_conductivity"] = solids / (conductivity + 1e-9)
    X["organic_ratio"] = organic / (solids + 1e-9)

    return X.values

# %%
preprocessing_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("outliers", FunctionTransformer(clip_outliers)),
    ("features", FunctionTransformer(add_features)),
    ("scaler", StandardScaler())
])

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

gb = GradientBoostingClassifier(
    n_estimators=200,
    learning_rate=0.1,
    random_state=42
)

final_classifier = StackingClassifier(
    estimators=[
        ("rf", rf),
        ("gb", gb)
    ],
    final_estimator=LogisticRegression(
        C=1.0,
        max_iter=1000
    ),
    passthrough=False
)

# %%
final_model = Pipeline([
    ("preprocessing", preprocessing_pipeline),
    ("model", final_classifier)
])

# %%
final_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                                  ('outliers',
#                                   FunctionTransformer(func=<function clip_outliers at 0x000001BC39325620>)),
#                                  ('features',
#                                   FunctionTransformer(func=<function add_features at 0x000001BC39394040>)),
#                                  ('scaler', StandardScaler())])),
#                 ('model',
#                  StackingClassifier(estimators=[('rf',
#                                                  RandomForestClassifier(n_estimators=200,
#                                                                         random_state=42)),
#                                                 ('gb',
#                                                  GradientBoostingClassifier(n_estimators=200,
#                                                                             random_state=42))],
#                                     final_estimator=LogisticRegression(max_iter=1000)))])

# %%
joblib.dump(final_model, "water_potability_model.pkl")
# Out:
# ['water_potability_model.pkl']

# %%
loaded_model = joblib.load("water_potability_model.pkl")

print("Model loaded successfully!")
# Out:
# Model loaded successfully!
